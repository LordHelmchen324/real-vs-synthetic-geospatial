# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import osmnx as ox
import pandas as pd
import seaborn as sns

# %%
# Load the data
df = pd.read_pickle('data_mdc/mdc.pkl')

# %%
df.head()
# Out:
#                           latitude  longitude  time_zone type
# user time
# 5448 2009-10-31 15:55:40  6.632476  46.520321      -7200  gps
#      2009-10-31 16:34:37  6.592562  46.523943      -7200  gps
#      2009-10-31 16:34:46  6.594179  46.524187      -7200  gps
#      2009-10-31 16:34:46  6.594179  46.524187      -7200  gps
#      2009-10-31 16:34:57  6.596068  46.523909      -7200  gps

# %%
# Load the small OSMNX graph of Lausanne
streets_beijing = ox.load_graphml('beijing_streets_all.graphml', folder='osmnx_data')

# %%
bj_edges = ox.graph_to_gdfs(streets_beijing, nodes=False, fill_edge_geometry=True)
bj_west, bj_south, bj_east, bj_north = bj_edges.total_bounds
print(bj_west, bj_south, bj_east, bj_north)
# Out:
# 115.4195287 39.4481847 117.4509195 41.0541939

# %%
ox.plot_graph(streets_beijing, fig_height=24, node_size=0, edge_linewidth=0.25)
# Out:
# (<Figure size 2185.69x1728 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1b2e565dd8>)
