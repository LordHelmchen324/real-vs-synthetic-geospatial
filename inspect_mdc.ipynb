# %%
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
mdc = pd.read_pickle('data_mdc/mdc.pkl')

# %%
mdc.head()
# Out:
#                           latitude  longitude  time_zone type
# user time
# 5448 2009-10-31 15:55:40  6.632476  46.520321      -7200  gps
#      2009-10-31 16:34:37  6.592562  46.523943      -7200  gps
#      2009-10-31 16:34:46  6.594179  46.524187      -7200  gps
#      2009-10-31 16:34:46  6.594179  46.524187      -7200  gps
#      2009-10-31 16:34:57  6.596068  46.523909      -7200  gps

# %%
len(mdc)
# Out:
# 13678618

# %%
print(mdc.index.levels[1].min())
print(mdc.index.levels[1].max())
# Out:
# 2009-09-01 05:30:33
# 2011-03-31 22:19:32

# %%
plt.figure(figsize=(18, 18))
plt.scatter(mdc['latitude'], mdc['longitude'], s=0.25)

# %%
plt.figure(figsize=(18, 18))
img = cimgt.GoogleTiles()
ax = plt.axes(projection = img.crs)
ax.add_image(img, 8, interpolation = 'bicubic')

plt.scatter(mdc['latitude'], mdc['longitude'], s=0.25, transform=ccrs.PlateCarree())
