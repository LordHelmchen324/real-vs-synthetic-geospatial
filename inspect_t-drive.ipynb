# %%
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
tdrive = pd.read_pickle('data_t-drive/t-drive.pkl')

# %%
tdrive.head()
# Out:
#                           longitude  latitude
# user time
# 3644 2008-02-02 13:40:59  116.37497  39.85789
#      2008-02-02 13:42:11  116.37542  39.85764
#      2008-02-02 13:42:49  116.37727  39.85775
#      2008-02-02 13:42:59  116.37746  39.85787
#      2008-02-02 13:44:00  116.37749  39.85817

# %%
len(tdrive)
# Out:
# 17662984

# %%
plt.figure(figsize=(18, 18))
plt.scatter(tdrive['longitude'], tdrive['latitude'], s=0.25)

# %%
plt.figure(figsize=(18, 18))
img = cimgt.GoogleTiles()
ax = plt.axes(projection = img.crs)
ax.add_image(img, 5, interpolation = 'bicubic')

plt.scatter(tdrive['longitude'], tdrive['latitude'], s=0.25, transform=ccrs.PlateCarree())
